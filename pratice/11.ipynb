# %%
import pandas as pd
import numpy as np
# Out:
# C:\Users\Atharva\AppData\Local\Temp\ipykernel_7328\2162656668.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df=pd.read_csv("../11/movies_metadata.csv")
df.head()
# Out:
# C:\Users\Atharva\AppData\Local\Temp\ipykernel_7328\471891643.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("../11/movies_metadata.csv")
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
# ...

# %%
df['original_language'].unique()
# Out:
# array(['en', 'fr', 'zh', 'it', 'fa', 'nl', 'de', 'cn', 'ar', 'es', 'ru',
#        'sv', 'ja', 'ko', 'sr', 'bn', 'he', 'pt', 'wo', 'ro', 'hu', 'cy',
#        'vi', 'cs', 'da', 'no', 'nb', 'pl', 'el', 'sh', 'xx', 'mk', 'bo',
#        'ca', 'fi', 'th', 'sk', 'bs', 'hi', 'tr', 'is', 'ps', 'ab', 'eo',
#        'ka', 'mn', 'bm', 'zu', 'uk', 'af', 'la', 'et', 'ku', 'fy', 'lv',
#        'ta', 'sl', 'tl', 'ur', 'rw', 'id', 'bg', 'mr', 'lt', 'kk', 'ms',
#        'sq', nan, '104.0', 'qu', 'te', 'am', 'jv', 'tg', 'ml', 'hr', 'lo',
#        'ay', 'kn', 'eu', 'ne', 'pa', 'ky', 'gl', '68.0', 'uz', 'sm', 'mt',
#        '82.0', 'hy', 'iu', 'lb', 'si'], dtype=object)

# %%
subset1=df[df['original_language']=='en']
subset2=df[df['original_language']=='fr']

# %%
merge=pd.concat([subset1,subset2])
merge
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45444  False                                                NaN         0
# 45447  False                                                NaN         0
# 45448  False                                                NaN         0
# 45450  False                                                NaN         0
# 45451  False                                                NaN         0
#
#                                                   genres  \
# ...

# %%
rating=pd.read_csv("../11/ratings_small.csv")
rating.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1       31     2.5  1260759144
# 1       1     1029     3.0  1260759179
# 2       1     1061     3.0  1260759182
# 3       1     1129     2.0  1260759185
# 4       1     1172     4.0  1260759205

# %%
sort=rating.sort_values(by="rating")
sort
# Out:
#        userId  movieId  rating   timestamp
# 75815     527     2355     0.5  1281234001
# 92912     615   109187     0.5  1454913681
# 12618      79        7     0.5  1182995062
# 63681     457   122882     0.5  1471383595
# 2491       15   101112     0.5  1465880292
# ...       ...      ...     ...         ...
# 65490     466     1639     5.0   945140370
# 65494     466     1688     5.0   944979201
# 26076     190     3176     5.0   975695243
# 9385       62    79132     5.0  1451708501
# 8086       52     4014     5.0  1231769672
#
# [100004 rows x 4 columns]

# %%
transpose=df.transpose()
transpose
# Out:
#                                                                    0      \
# adult                                                              False
# belongs_to_collection  {'id': 10194, 'name': 'Toy Story Collection', ...
# budget                                                          30000000
# genres                 [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# homepage                            http://toystory.disney.com/toy-story
# id                                                                   862
# imdb_id                                                        tt0114709
# original_language                                                     en
# original_title                                                 Toy Story
# overview               Led by Woody, Andy's toys live happily in his ...
# popularity                                                     21.946943
# poster_path                             /rhIRbceoE9lR4veEXuwCC2wARtG.jpg
# ...

# %%
melt=pd.melt(df,id_vars=['id','original_language'],var_name='Metric',value_name='value')
melt
# Out:
#              id original_language      Metric  value
# 0           862                en       adult  False
# 1          8844                en       adult  False
# 2         15602                en       adult  False
# 3         31357                en       adult  False
# 4         11862                en       adult  False
# ...         ...               ...         ...    ...
# 1000247  439050                fa  vote_count    1.0
# 1000248  111109                tl  vote_count    3.0
# 1000249   67758                en  vote_count    6.0
# 1000250  227506                en  vote_count    0.0
# 1000251  461257                en  vote_count    0.0
#
# [1000252 rows x 4 columns]

# %%
cast=pd.pivot_table(df,index=['id','original_language'])
cast
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\Atharva\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File c:\Users\Atharva\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\ops.py:863, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     861     preserve_dtype = True
# --> 863 result = self._aggregate_series_pure_python(obj, func)
#     865 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File c:\Users\Atharva\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\ops.py:884, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
# ...
